# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env = UnityEnvironment(file_name='./Reacher_Windows_x86_64/Reacher.exe')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_size -> 5.0
# 		goal_speed -> 1.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 1
# Size of each action: 4
# There are 1 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726671e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
# Out:
# Total score (averaged over agents) this episode: 0.0

# %% [markdown]
# ### 4. Imports

# %%
import random
import torch
import time
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 5. Train the agent with DDPG
# As seen above, the state and action spaces are continuous. Hence, value based methods such as DQN would not be directly applicable in this case.
# This notebook implements the Deep Deterministic Policy Gradients (DDPG) method for training the agent.
# <br>Please refer the ddpg_agent script for Agent class.

# %%
print(torch.__version__)
# Out:
# 0.4.0

# %%
import ddpg_agent
import torch.optim as optim
import importlib

importlib.reload(ddpg_agent)

agent = ddpg_agent.Agent(state_size=state_size, action_size=action_size, random_seed = 0)

# %%
def ddpg(n_episodes=500, max_t=1000, print_every=100):

    """DDPG Algorithm.
    
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        print_every (int): frequency of printing information throughout iteration """
    
    scores = []
    scores_deque = deque(maxlen=print_every)
    training_start_time = time.time()

    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]
        agent.reset()
        state = env_info.vector_observations[0]            # get the current state
        score = 0
        
        start_time = time.time()
        for t in range(max_t):
            print('\rt {}'.format(t), end="")
            action = agent.act(state)          # select an action
            env_info = env.step(action)[brain_name]        # send the action to the environment
            next_state = env_info.vector_observations[0]   # get the next state
            reward = env_info.rewards[0]                   # get the reward
            done = env_info.local_done[0]                  # see if episode has finished
            agent.step(state, action, reward, next_state, done) # take step with agent (including learning)
            score += reward                                # update the score
            state = next_state                             # roll over the state to next time step
            if done:                                       # exit loop if episode finished
                agent.finalize_log_writing()
                break
        
        scores_deque.append(score)       # save most recent score
        scores.append(score)             # save most recent score
        duration = time.time() - start_time
        duration_str = time.strftime('%Mm%Ss', time.gmtime(duration))
        
        print('       Episode {} ({})\tAverage Score: {:.2f}'.format(i_episode, duration_str, np.mean(scores_deque)))
        agent.write_score(score, i_episode)
        agent.write_mean_score(np.mean(scores_deque),  i_episode)
        
        if i_episode % print_every == 0:
            print('Saving checkpoint...')
            torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
        
        if np.mean(scores_deque)>=30.0:
            training_time = time.time() - training_start_time
            training_time_str = time.strftime('%Hh%Mm%Ss', time.gmtime(training_time))

            print('\nEnvironment solved in {:d} episodes! ({}) \tAverage Score: {:.2f}'.format(i_episode, training_time_str, np.mean(scores_deque)))
            torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
            agent.finalize_log_writing()
            break
            
    return scores

# %%
print(agent.actor_local)
print(agent.critic_local)
scores = ddpg()
# Out:
# Actor(
#   (fc1): Linear(in_features=33, out_features=400, bias=True)
#   (bn1): BatchNorm1d(400, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=400, out_features=300, bias=True)
#   (bn2): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=300, out_features=4, bias=True)
# )
# Critic(
#   (fcs1): Linear(in_features=33, out_features=400, bias=True)
#   (bn1): BatchNorm1d(400, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=404, out_features=300, bias=True)
#   (fc3): Linear(in_features=300, out_features=1, bias=True)
# )
# t 999       Episode 1 (00m26s)	Average Score: 0.08
# t 999       Episode 2 (00m27s)	Average Score: 0.23
# t 999       Episode 3 (00m28s)	Average Score: 0.27
# t 999       Episode 4 (00m27s)	Average Score: 0.20
# t 999       Episode 5 (00m27s)	Average Score: 0.26
# t 999       Episode 6 (00m29s)	Average Score: 0.25
# t 999       Episode 7 (00m30s)	Average Score: 0.21
# t 999       Episode 8 (00m35s)	Average Score: 0.21
# t 999       Episode 9 (00m32s)	Average Score: 0.28
# t 999       Episode 10 (00m29s)	Average Score: 0.36
# t 999       Episode 11 (00m28s)	Average Score: 0.36
# t 999       Episode 12 (00m30s)	Average Score: 0.33
# t 999       Episode 13 (00m31s)	Average Score: 0.34
# t 999       Episode 14 (00m33s)	Average Score: 0.34
# t 999       Episode 15 (00m29s)	Average Score: 0.38
# t 999       Episode 16 (00m26s)	Average Score: 0.39
# t 999       Episode 17 (00m26s)	Average Score: 0.42
# t 999       Episode 18 (00m26s)	Average Score: 0.40
# t 999       Episode 19 (00m26s)	Average Score: 0.39
# t 999       Episode 20 (00m26s)	Average Score: 0.39
# t 999       Episode 21 (00m26s)	Average Score: 0.46
# t 999       Episode 22 (00m25s)	Average Score: 0.53
# t 999       Episode 23 (00m25s)	Average Score: 0.57
# t 999       Episode 24 (00m26s)	Average Score: 0.58
# t 999       Episode 25 (00m26s)	Average Score: 0.62
# t 999       Episode 26 (00m26s)	Average Score: 0.62
# t 999       Episode 27 (00m26s)	Average Score: 0.64
# t 999       Episode 28 (00m25s)	Average Score: 0.69
# t 999       Episode 29 (00m26s)	Average Score: 0.73
# t 999       Episode 30 (00m26s)	Average Score: 0.73
# t 999       Episode 31 (00m25s)	Average Score: 0.78
# t 999       Episode 32 (00m25s)	Average Score: 0.81
# t 999       Episode 33 (00m28s)	Average Score: 0.84
# t 999       Episode 34 (00m28s)	Average Score: 0.87
# t 999       Episode 35 (00m29s)	Average Score: 0.90
# t 999       Episode 36 (00m29s)	Average Score: 0.89
# t 999       Episode 37 (00m28s)	Average Score: 0.89
# t 999       Episode 38 (00m34s)	Average Score: 0.92
# t 999       Episode 39 (00m34s)	Average Score: 0.93
# t 999       Episode 40 (00m30s)	Average Score: 0.96
# t 999       Episode 41 (00m42s)	Average Score: 0.96
# t 999       Episode 42 (00m50s)	Average Score: 0.99
# t 999       Episode 43 (00m26s)	Average Score: 1.02
# t 999       Episode 44 (00m30s)	Average Score: 1.05
# t 999       Episode 45 (00m29s)	Average Score: 1.04
# t 999       Episode 46 (00m26s)	Average Score: 1.07
# t 999       Episode 47 (00m26s)	Average Score: 1.10
# t 999       Episode 48 (00m26s)	Average Score: 1.10
# t 999       Episode 49 (00m29s)	Average Score: 1.11
# t 999       Episode 50 (00m29s)	Average Score: 1.13
# t 999       Episode 51 (00m27s)	Average Score: 1.17
# t 999       Episode 52 (00m30s)	Average Score: 1.20
# t 999       Episode 53 (00m29s)	Average Score: 1.23
# t 999       Episode 54 (00m28s)	Average Score: 1.27
# t 999       Episode 55 (00m26s)	Average Score: 1.27
# t 999       Episode 56 (00m26s)	Average Score: 1.30
# t 999       Episode 57 (00m26s)	Average Score: 1.30
# t 999       Episode 58 (00m26s)	Average Score: 1.29
# t 999       Episode 59 (00m27s)	Average Score: 1.30
# t 999       Episode 60 (00m26s)	Average Score: 1.29
# t 999       Episode 61 (00m26s)	Average Score: 1.29
# t 999       Episode 62 (00m26s)	Average Score: 1.30
# t 999       Episode 63 (00m26s)	Average Score: 1.28
# t 999       Episode 64 (00m26s)	Average Score: 1.28
# t 999       Episode 65 (00m25s)	Average Score: 1.32
# t 999       Episode 66 (00m25s)	Average Score: 1.33
# t 999       Episode 67 (00m31s)	Average Score: 1.33
# t 999       Episode 68 (00m28s)	Average Score: 1.43
# t 999       Episode 69 (00m31s)	Average Score: 1.45
# t 999       Episode 70 (00m28s)	Average Score: 1.50
# t 999       Episode 71 (00m28s)	Average Score: 1.50
# t 999       Episode 72 (00m28s)	Average Score: 1.53
# t 999       Episode 73 (00m32s)	Average Score: 1.54
# t 999       Episode 74 (00m31s)	Average Score: 1.56
# t 999       Episode 75 (00m28s)	Average Score: 1.57
# t 999       Episode 76 (00m32s)	Average Score: 1.59
# t 999       Episode 77 (00m29s)	Average Score: 1.60
# t 999       Episode 78 (00m29s)	Average Score: 1.61
# t 999       Episode 79 (00m29s)	Average Score: 1.63
# t 999       Episode 80 (00m27s)	Average Score: 1.64
# t 999       Episode 81 (00m28s)	Average Score: 1.63
# t 999       Episode 82 (00m27s)	Average Score: 1.69
# t 999       Episode 83 (00m27s)	Average Score: 1.76
# t 999       Episode 84 (00m26s)	Average Score: 1.75
# t 999       Episode 85 (00m26s)	Average Score: 1.76
# t 999       Episode 86 (00m27s)	Average Score: 1.79
# t 999       Episode 87 (00m28s)	Average Score: 1.79
# t 999       Episode 88 (00m30s)	Average Score: 1.77
# t 999       Episode 89 (00m28s)	Average Score: 1.81
# t 999       Episode 90 (00m30s)	Average Score: 1.94
# t 999       Episode 91 (00m33s)	Average Score: 1.98
# t 999       Episode 92 (00m29s)	Average Score: 2.00
# t 999       Episode 93 (00m29s)	Average Score: 2.01
# t 999       Episode 94 (00m29s)	Average Score: 2.01
# t 999       Episode 95 (00m30s)	Average Score: 2.03
# t 999       Episode 96 (00m31s)	Average Score: 2.05
# t 999       Episode 97 (00m31s)	Average Score: 2.06
# t 999       Episode 98 (00m39s)	Average Score: 2.08
# t 999       Episode 99 (00m56s)	Average Score: 2.12
# t 999       Episode 100 (01m30s)	Average Score: 2.13
# Saving checkpoint...
# t 999       Episode 101 (00m38s)	Average Score: 2.18
# t 999       Episode 102 (00m31s)	Average Score: 2.21
# t 999       Episode 103 (00m26s)	Average Score: 2.26
# t 999       Episode 104 (00m26s)	Average Score: 2.30
# t 999       Episode 105 (00m26s)	Average Score: 2.36
# t 999       Episode 106 (00m26s)	Average Score: 2.40
# t 999       Episode 107 (00m26s)	Average Score: 2.46
# t 999       Episode 108 (00m26s)	Average Score: 2.51
# t 999       Episode 109 (00m26s)	Average Score: 2.58
# t 999       Episode 110 (00m27s)	Average Score: 2.64
# t 999       Episode 111 (00m26s)	Average Score: 2.69
# t 999       Episode 112 (00m27s)	Average Score: 2.75
# t 999       Episode 113 (00m28s)	Average Score: 2.82
# t 999       Episode 114 (00m26s)	Average Score: 2.89
# t 999       Episode 115 (00m27s)	Average Score: 2.95
# t 999       Episode 116 (00m26s)	Average Score: 3.02
# t 999       Episode 117 (00m27s)	Average Score: 3.07
# t 999       Episode 118 (00m27s)	Average Score: 3.12
# t 999       Episode 119 (00m26s)	Average Score: 3.22
# t 999       Episode 120 (00m27s)	Average Score: 3.33
# t 999       Episode 121 (00m27s)	Average Score: 3.42
# t 999       Episode 122 (00m27s)	Average Score: 3.46
# t 999       Episode 123 (00m27s)	Average Score: 3.50
# t 999       Episode 124 (00m26s)	Average Score: 3.60
# t 999       Episode 125 (00m27s)	Average Score: 3.67
# t 999       Episode 126 (00m26s)	Average Score: 3.76
# t 999       Episode 127 (00m27s)	Average Score: 3.88
# t 999       Episode 128 (00m27s)	Average Score: 3.97
# t 999       Episode 129 (00m27s)	Average Score: 4.04
# t 999       Episode 130 (00m27s)	Average Score: 4.15
# t 999       Episode 131 (00m27s)	Average Score: 4.21
# t 999       Episode 132 (00m27s)	Average Score: 4.36
# t 999       Episode 133 (00m27s)	Average Score: 4.42
# t 999       Episode 134 (00m28s)	Average Score: 4.49
# t 999       Episode 135 (00m28s)	Average Score: 4.62
# t 999       Episode 136 (00m28s)	Average Score: 4.69
# t 999       Episode 137 (00m29s)	Average Score: 4.82
# t 999       Episode 138 (00m30s)	Average Score: 4.89
# t 999       Episode 139 (00m30s)	Average Score: 5.03
# t 999       Episode 140 (00m28s)	Average Score: 5.11
# t 999       Episode 141 (00m28s)	Average Score: 5.20
# t 999       Episode 142 (00m29s)	Average Score: 5.23
# t 999       Episode 143 (00m28s)	Average Score: 5.31
# t 999       Episode 144 (00m28s)	Average Score: 5.38
# t 999       Episode 145 (00m27s)	Average Score: 5.51
# t 999       Episode 146 (00m30s)	Average Score: 5.58
# t 999       Episode 147 (00m27s)	Average Score: 5.73
# t 999       Episode 148 (00m29s)	Average Score: 5.79
# t 999       Episode 149 (00m29s)	Average Score: 5.95
# t 999       Episode 150 (00m42s)	Average Score: 6.03
# t 999       Episode 151 (00m31s)	Average Score: 6.14
# t 999       Episode 152 (00m28s)	Average Score: 6.26
# t 999       Episode 153 (00m28s)	Average Score: 6.34
# t 999       Episode 154 (00m27s)	Average Score: 6.39
# t 999       Episode 155 (00m27s)	Average Score: 6.49
# t 999       Episode 156 (00m28s)	Average Score: 6.61
# t 999       Episode 157 (00m28s)	Average Score: 6.75
# t 999       Episode 158 (00m27s)	Average Score: 7.11
# t 999       Episode 159 (00m28s)	Average Score: 7.22
# t 999       Episode 160 (00m28s)	Average Score: 7.40
# t 999       Episode 161 (00m34s)	Average Score: 7.57
# t 999       Episode 162 (00m27s)	Average Score: 7.69
# t 999       Episode 163 (00m27s)	Average Score: 7.89
# t 999       Episode 164 (00m27s)	Average Score: 8.06
# t 999       Episode 165 (00m27s)	Average Score: 8.24
# t 999       Episode 166 (00m27s)	Average Score: 8.41
# t 999       Episode 167 (00m27s)	Average Score: 8.56
# t 999       Episode 168 (00m27s)	Average Score: 8.73
# t 999       Episode 169 (00m27s)	Average Score: 8.89
# t 999       Episode 170 (00m28s)	Average Score: 9.03
# t 999       Episode 171 (00m27s)	Average Score: 9.18
# t 999       Episode 172 (00m27s)	Average Score: 9.30
# t 999       Episode 173 (00m27s)	Average Score: 9.47
# t 999       Episode 174 (00m27s)	Average Score: 9.68
# t 999       Episode 175 (00m27s)	Average Score: 9.85
# t 999       Episode 176 (00m27s)	Average Score: 10.02
# t 999       Episode 177 (00m27s)	Average Score: 10.14
# t 999       Episode 178 (00m27s)	Average Score: 10.24
# t 999       Episode 179 (00m27s)	Average Score: 10.29
# t 999       Episode 180 (00m27s)	Average Score: 10.44
# t 999       Episode 181 (00m27s)	Average Score: 10.65
# t 999       Episode 182 (00m27s)	Average Score: 10.79
# t 999       Episode 183 (00m27s)	Average Score: 11.05
# t 999       Episode 184 (00m27s)	Average Score: 11.36
# t 999       Episode 185 (00m27s)	Average Score: 11.61
# t 999       Episode 186 (00m26s)	Average Score: 11.81
# t 999       Episode 187 (00m27s)	Average Score: 12.00
# t 999       Episode 188 (00m34s)	Average Score: 12.18
# t 999       Episode 189 (00m28s)	Average Score: 12.34
# t 999       Episode 190 (00m28s)	Average Score: 12.40
# t 999       Episode 191 (00m28s)	Average Score: 12.56
# t 999       Episode 192 (00m28s)	Average Score: 12.73
# t 999       Episode 193 (00m28s)	Average Score: 12.87
# t 999       Episode 194 (00m28s)	Average Score: 13.01
# t 999       Episode 195 (00m28s)	Average Score: 13.20
# t 999       Episode 196 (00m28s)	Average Score: 13.42
# t 999       Episode 197 (00m28s)	Average Score: 13.52
# t 999       Episode 198 (00m28s)	Average Score: 13.63
# t 999       Episode 199 (00m29s)	Average Score: 13.85
# t 999       Episode 200 (00m28s)	Average Score: 14.05
# Saving checkpoint...
# t 999       Episode 201 (00m28s)	Average Score: 14.24
# t 999       Episode 202 (00m28s)	Average Score: 14.37
# t 999       Episode 203 (00m28s)	Average Score: 14.51
# t 999       Episode 204 (00m29s)	Average Score: 14.73
# t 999       Episode 205 (00m28s)	Average Score: 14.98
# t 999       Episode 206 (00m28s)	Average Score: 15.18
# t 999       Episode 207 (00m28s)	Average Score: 15.20
# t 999       Episode 208 (00m28s)	Average Score: 15.21
# t 999       Episode 209 (00m28s)	Average Score: 15.24
# t 999       Episode 210 (00m28s)	Average Score: 15.50
# t 999       Episode 211 (00m29s)	Average Score: 15.79
# t 999       Episode 212 (00m28s)	Average Score: 15.81
# t 999       Episode 213 (00m34s)	Average Score: 16.03
# t 999       Episode 214 (00m31s)	Average Score: 16.19
# t 999       Episode 215 (00m33s)	Average Score: 16.45
# t 999       Episode 216 (00m33s)	Average Score: 16.58
# t 999       Episode 217 (00m32s)	Average Score: 16.74
# t 999       Episode 218 (00m31s)	Average Score: 16.95
# t 999       Episode 219 (00m29s)	Average Score: 17.21
# t 999       Episode 220 (00m28s)	Average Score: 17.36
# t 999       Episode 221 (00m28s)	Average Score: 17.61
# t 999       Episode 222 (00m28s)	Average Score: 17.88
# t 999       Episode 223 (00m28s)	Average Score: 18.12
# t 999       Episode 224 (00m29s)	Average Score: 18.36
# t 999       Episode 225 (00m28s)	Average Score: 18.61
# t 999       Episode 226 (00m28s)	Average Score: 18.81
# t 999       Episode 227 (00m31s)	Average Score: 18.92
# t 999       Episode 228 (00m32s)	Average Score: 19.18
# t 999       Episode 229 (00m31s)	Average Score: 19.35
# t 999       Episode 230 (00m29s)	Average Score: 19.47
# t 999       Episode 231 (00m30s)	Average Score: 19.72
# t 999       Episode 232 (00m30s)	Average Score: 19.94
# t 999       Episode 233 (00m29s)	Average Score: 20.25
# t 999       Episode 234 (00m30s)	Average Score: 20.48
# t 999       Episode 235 (00m30s)	Average Score: 20.70
# t 999       Episode 236 (00m29s)	Average Score: 20.96
# t 999       Episode 237 (00m30s)	Average Score: 21.22
# t 999       Episode 238 (00m29s)	Average Score: 21.46
# t 999       Episode 239 (00m30s)	Average Score: 21.70
# t 999       Episode 240 (00m30s)	Average Score: 21.98
# t 999       Episode 241 (00m29s)	Average Score: 22.25
# t 999       Episode 242 (00m28s)	Average Score: 22.53
# t 999       Episode 243 (00m28s)	Average Score: 22.81
# t 999       Episode 244 (00m28s)	Average Score: 23.07
# t 999       Episode 245 (00m27s)	Average Score: 23.32
# t 999       Episode 246 (00m28s)	Average Score: 23.56
# t 999       Episode 247 (00m28s)	Average Score: 23.75
# t 999       Episode 248 (00m27s)	Average Score: 24.06
# t 999       Episode 249 (00m28s)	Average Score: 24.26
# t 999       Episode 250 (00m27s)	Average Score: 24.55
# t 999       Episode 251 (00m28s)	Average Score: 24.77
# t 999       Episode 252 (00m28s)	Average Score: 24.95
# t 999       Episode 253 (00m28s)	Average Score: 25.22
# t 999       Episode 254 (00m28s)	Average Score: 25.52
# t 999       Episode 255 (00m28s)	Average Score: 25.79
# t 999       Episode 256 (00m29s)	Average Score: 25.99
# t 999       Episode 257 (00m28s)	Average Score: 26.23
# t 999       Episode 258 (00m28s)	Average Score: 26.20
# t 999       Episode 259 (00m28s)	Average Score: 26.44
# t 999       Episode 260 (00m28s)	Average Score: 26.62
# t 999       Episode 261 (00m29s)	Average Score: 26.82
# t 999       Episode 262 (00m28s)	Average Score: 27.05
# t 999       Episode 263 (00m28s)	Average Score: 27.25
# t 999       Episode 264 (00m28s)	Average Score: 27.46
# t 999       Episode 265 (00m27s)	Average Score: 27.63
# t 999       Episode 266 (00m28s)	Average Score: 27.82
# t 999       Episode 267 (00m28s)	Average Score: 28.05
# t 999       Episode 268 (00m29s)	Average Score: 28.19
# t 999       Episode 269 (00m28s)	Average Score: 28.38
# t 999       Episode 270 (00m28s)	Average Score: 28.53
# t 999       Episode 271 (00m29s)	Average Score: 28.75
# t 999       Episode 272 (00m28s)	Average Score: 28.97
# t 999       Episode 273 (00m29s)	Average Score: 29.14
# t 999       Episode 274 (00m28s)	Average Score: 29.24
# t 999       Episode 275 (00m29s)	Average Score: 29.42
# t 999       Episode 276 (00m28s)	Average Score: 29.60
# t 999       Episode 277 (00m27s)	Average Score: 29.84
# t 999       Episode 278 (00m28s)	Average Score: 30.09
#
# Environment solved in 278 episodes! (02h15m01s) 	Average Score: 30.09

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
fig.savefig('rewards_plot.png', dpi=fig.dpi)
plt.show()

# %% [markdown]
# ### 6. Watch a Smart Agent!
# In the next code cell, you will load the trained weights from file to watch a smart agent!

# %%
import ddpg_agent
import torch.optim as optim
import importlib

importlib.reload(ddpg_agent)

agent = ddpg_agent.Agent(state_size=state_size, action_size=action_size, random_seed = 0)

agent.actor_local.load_state_dict(torch.load('checkpoint_actor.pth'))
agent.critic_local.load_state_dict(torch.load('checkpoint_critic.pth'))


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

env_info = env.reset(train_mode=False)[brain_name] # reset the environment
state = env_info.vector_observations[0]            # get the current state
score = 0                                          # initialize the score

for j in range(1000):
    action_probs = agent.act(state)                # select an action
    env_info = env.step(action_probs)[brain_name]  # send the action to the environment
    next_state = env_info.vector_observations[0]   # get the next state
    reward = env_info.rewards[0]                   # get the reward
    done = env_info.local_done[0]                  # see if episode has finished
    score += reward                                # update the score
    state = next_state                             # roll over the state to next time step
    if done:                                       # exit loop if episode finished
        break

print("Score: {}".format(score))
# Out:
# Score: 38.90999913029373

# %% [markdown]
# When finished, you can close the environment.

# %%
env.close()
